# %% [markdown]
# ## Data Preprocessing and EDA

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import re 
from wordcloud import WordCloud

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 
import string
from nltk.stem import WordNetLemmatizer
import matplotlib.pyplot as plt
import seaborn as sns

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sophia.bouchama\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sophia.bouchama\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\sophia.bouchama\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# Read in file
reviews_data = pd.read_csv("../data/Reviews.csv")

# %%
# Inspect first few rows
reviews_data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
# Check size of dataset
reviews_data.shape
# Out:
# (568454, 10)

# %%
# Inspect columns
reviews_data.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
# Check for null columns
reviews_data.isna().sum()
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               26
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %%
# Ensure text column doesn't contain null values or empty strings
(reviews_data['Text'].isna() | (reviews_data['Text']  == '')).value_counts()
# Out:
# Text
# False    568454
# Name: count, dtype: int64

# %% [markdown]
# ### Dealing with Duplicated Data

# %%
# Counting duplicated Text and User ID
reviews_data.duplicated(subset=['Text', 'UserId']).value_counts()
# Out:
# False    393606
# True     174848
# Name: count, dtype: int64

# %%
# Counting duplicated Text and Time
reviews_data.duplicated(subset=['Text', 'UserId', 'Time']).value_counts()
# Out:
# False    393892
# True     174562
# Name: count, dtype: int64

# %%
# Counting duplicated Text and Time
reviews_data.duplicated(subset=['Text', 'Time']).value_counts()
# Out:
# False    393885
# True     174569
# Name: count, dtype: int64

# %%
#reviews_data[reviews_data.duplicated(subset=['Text', 'Time'], keep=False)]

# %%
# Counting duplicated Text, User ID, ProductId, Time 
reviews_data.duplicated(subset=['Text', 'UserId', 'ProductId']).value_counts()
# Out:
# False    567145
# True       1309
# Name: count, dtype: int64

# %%
# Counting duplicated Text and User ID
reviews_data.duplicated(subset=['Text', 'UserId', 'ProductId', 'Time']).value_counts()
# Out:
# False    567249
# True       1205
# Name: count, dtype: int64

# %%
# Mark all duplicates (including the first occurrence)
reviews_data['IsDuplicate'] = reviews_data.duplicated(subset=['Text', 'UserId'], keep=False)

# %%
# Group by UserId and count the number of duplicates for each user
duplicate_counts_by_user = reviews_data[reviews_data['IsDuplicate']].groupby('UserId').size()

# Sort the counts to see users with the most duplicates
duplicate_counts_by_user_sorted = duplicate_counts_by_user.sort_values(ascending=False)

# Display the top users with the most duplicate reviews
print(duplicate_counts_by_user_sorted.head(10))
# Out:
# UserId
# A1YUL9PCJR3JTY    293
# A3OXHLG6DIBRW8    248
# A3TVZM3ZIXG8YW    199
# A1TMAVN4CEM8U8    188
# A29JUMRL1US6YP    170
# A281NPSIMI1C2R    165
# A2SZLNSI5KOQJT    135
# A3PJZ8TU8FDQ1K    124
# A1UQBFCERIP7VJ    114
# AKZKG2Z7CNV27     110
# dtype: int64

# %%
reviews_data[reviews_data['UserId'] == 'A1YUL9PCJR3JTY'].sort_values(by='ProductId').head()
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 447373  447374  B0000C69FI  A1YUL9PCJR3JTY  O. Brown "Ms. O. Khannah-Brown"
# 67141    67142  B0000CGFSC  A1YUL9PCJR3JTY  O. Brown "Ms. O. Khannah-Brown"
# 332766  332767  B0000DBN1F  A1YUL9PCJR3JTY  O. Brown "Ms. O. Khannah-Brown"
# 375974  375975  B0000DBN1I  A1YUL9PCJR3JTY  O. Brown "Ms. O. Khannah-Brown"
# 375937  375938  B0000DBN1L  A1YUL9PCJR3JTY  O. Brown "Ms. O. Khannah-Brown"
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 447373                     1                       1      4  1283817600
# 67141                      1                       1      5  1170374400
# 332766                    79                      82      4  1158278400
# 375974                     3                       3      4  1158192000
# 375937                    15                      16      4  1158192000
#
#                                          Summary  \
# 447373         Subtle, Mild, Enjoyable Green Tea
# 67141   Distinctive, great-flavored Japanese tea
# 332766   Good Teas Overall, But Tazo Disappoints
# 375974                        Nice Chamomile Tea
# 375937                 Enjoyable Chai Experience
#
#                                                      Text  IsDuplicate
# 447373  ****<br />Tazo's Zen Green Tea with Lemongrass...         True
# 67141   *****<br />Ashby's Japanese Green Tea is a dis...         True
# 332766  ****<br /><br />Tazo Assorted Black and Green ...         True
# 375974  ****<br />Tazo's Calm Herbal Infusion is a nic...         True
# 375937  ****<br /><br />Tazo's Chai Black Tea is an en...         True

# %%
reviews_data = reviews_data.drop_duplicates(subset=["UserId","Time","Text"])

# %%
reviews_data.shape
# Out:
# (393892, 11)

# %%
# Plot the distribution of Score
sns.countplot(x="Score", data=reviews_data)
# Out:
# <Axes: xlabel='Score', ylabel='count'>

# %%
# Plot the distribution of HelpfulnessNumerator
sns.countplot(x="HelpfulnessNumerator", data=reviews_data)
# Out:
# <Axes: xlabel='HelpfulnessNumerator', ylabel='count'>

# %%
reviews_data.boxplot('HelpfulnessNumerator')
# Out:
# <Axes: >

# %%
# Plot the distribution of HelpfulnessDenominator
sns.countplot(x="HelpfulnessDenominator", data=reviews_data)
# Out:
# <Axes: xlabel='HelpfulnessDenominator', ylabel='count'>

# %%
sns.boxplot(x="HelpfulnessDenominator", data=reviews_data)
# Out:
# <Axes: xlabel='HelpfulnessDenominator'>

# %%
# HelpfulnessDenominator should be greater than or equal to HelpfulnessNumerator. Remove those that do not satisfy this condition 
reviews_data = reviews_data[reviews_data["HelpfulnessNumerator"] <= reviews_data["HelpfulnessDenominator"]]

# %%
# Recheck the count
reviews_data.shape
# Out:
# (393890, 11)

# %%
# Check the datatypes of the columns
reviews_data.dtypes
# Out:
# Id                         int64
# ProductId                 object
# UserId                    object
# ProfileName               object
# HelpfulnessNumerator       int64
# HelpfulnessDenominator     int64
# Score                      int64
# Time                       int64
# Summary                   object
# Text                      object
# IsDuplicate                 bool
# dtype: object

# %%
# Convert the Time column into datetime format
reviews_data['Time'] = pd.to_datetime(reviews_data['Time'], unit='s')

# %%
# Inspect the Time column values
reviews_data['Time'].head()
# Out:
# 0   2011-04-27
# 1   2012-09-07
# 2   2008-08-18
# 3   2011-06-13
# 4   2012-10-21
# Name: Time, dtype: datetime64[ns]

# %%
# Create a Month column from the Time data
reviews_data['Month'] = reviews_data['Time'].dt.month

# Create a Year column from the Time data
reviews_data['Year'] = reviews_data['Time'].dt.year

# Create a YearMonth column from the Time data
reviews_data['YearMonth'] = reviews_data['Time'].dt.to_period('M')  # This creates a period for each month of each year

# %%
# Plot the Average Review Scores Over Time
average_scores = reviews_data.groupby('YearMonth')['Score'].mean().reset_index()
average_scores['YearMonth'] = average_scores['YearMonth'].dt.to_timestamp()

# Now plotting with Seaborn should work
plt.figure(figsize=(14, 7))
sns.lineplot(data=average_scores, x='YearMonth', y='Score')
plt.xticks(rotation=45)
plt.title('Average Review Scores Over Time')
plt.xlabel('Year and Month')
plt.ylabel('Average Score')
plt.show()
# Out:
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plot the Number of Reviews Over Time
review_counts = reviews_data.groupby('YearMonth').size().reset_index(name='ReviewCount')
review_counts['YearMonth'] = review_counts['YearMonth'].dt.to_timestamp()

# Plotting with Seaborn
plt.figure(figsize=(14, 7))
sns.lineplot(data=review_counts, x='YearMonth', y='ReviewCount')
plt.xticks(rotation=45)
plt.title('Number of Reviews Over Time')
plt.xlabel('Year and Month')
plt.ylabel('Number of Reviews')
plt.show()
# Out:
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Create columns for Positive, Negative and Neutral Reviews based on Score
reviews_data['PositiveReviews'] = reviews_data['Score'] > 3
reviews_data['NegativeReviews'] = reviews_data['Score'] < 3
reviews_data['NeutralReviews'] = reviews_data['Score'] == 3

# %%
# Generate a wordcloud for positive and negative reviews

# Filter the reviews based on the boolean columns and join them into a single string for word cloud generation.
positive_reviews_text = " ".join(reviews_data[reviews_data['PositiveReviews']]['Text'])
negative_reviews_text = " ".join(reviews_data[reviews_data['NegativeReviews']]['Text'])

# Generate a word cloud image for positive reviews.
wordcloud_pos = WordCloud(max_font_size=100, max_words=100, background_color="white").generate(positive_reviews_text)

# Display the generated image for positive reviews.
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud_pos, interpolation='bilinear')
plt.axis("off")
plt.title('Word Cloud for Positive Reviews')
plt.show()

# Generate a word cloud image for negative reviews.
wordcloud_neg = WordCloud(max_font_size=100, max_words=100, background_color="white").generate(negative_reviews_text)

# Display the generated image for negative reviews.
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud_neg, interpolation='bilinear')
plt.axis("off")
plt.title('Word Cloud for Negative Reviews')
plt.show()

# %%
# Calculate review lengths
reviews_data['ReviewLength'] = reviews_data['Text'].apply(len)

# Histogram for Review Lengths
plt.figure(figsize=(10, 6))
sns.histplot(data=reviews_data, x='ReviewLength', bins=30, kde=True)
plt.title('Distribution of Review Lengths')
plt.xlabel('Review Length')
plt.ylabel('Frequency')
plt.show()
# Out:
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Create a preprocessing function with optional steps
def preprocessing(sentence, remove_html=True, lowercasing=True, remove_numbers=True, remove_punctuation=True, tokenize=True, remove_stopwords=True, lemmatize=True):

    # Removing whitespaces
    sentence = sentence.strip()

    # Removing HTML tags
    if remove_html:
        sentence = re.sub(r'<.*?>', '', sentence)

    # Lowercasing
    if lowercasing:
        sentence = sentence.lower()

    # Removing numbers
    if remove_numbers:
        sentence = ''.join(char for char in sentence if not char.isdigit())

    # Removing punctuation
    if remove_punctuation:
        for punctuation in string.punctuation:
            sentence = sentence.replace(punctuation, '')

    # Tokenizing
    if tokenize:    
        sentence = word_tokenize(sentence)

    # Removing stopwords
    if remove_stopwords and tokenize:
        stop_words = set(stopwords.words('english'))
        sentence = [word for word in sentence if word not in stop_words]

    # Lemmatizing
    if lemmatize and tokenize:
        lemmatizer = WordNetLemmatizer()
        lemmatized = [lemmatizer.lemmatize(word) for word in sentence]
        sentence = " ".join(lemmatized)

    return sentence

# %%
reviews_data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score       Time  \
# 0                     1                       1      5 2011-04-27
# 1                     0                       0      1 2012-09-07
# 2                     1                       1      4 2008-08-18
# 3                     3                       3      2 2011-06-13
# 4                     0                       0      5 2012-10-21
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...
#
#    IsDuplicate  Month  Year YearMonth  PositiveReviews  NegativeReviews  \
# 0        False      4  2011   2011-04             True            False
# 1        False      9  2012   2012-09            False             True
# 2        False      8  2008   2008-08             True            False
# 3         True      6  2011   2011-06            False             True
# 4        False     10  2012   2012-10             True            False
#
#    NeutralReviews  ReviewLength
# 0           False           263
# 1           False           190
# 2           False           509
# 3           False           219
# 4           False           140

# %% [markdown]
# ## Roberta (Hugging Face) Model

# %% [markdown]
# Firstly, we need to create our labelled data to create a binary classification problem.
#
# label 0 = negative review
#
# label 1 = positive review
#
#
# Where positive review is > 3 and negative review is < 3.

# %% [markdown]
# Create a copy of the dataframe in order to apply specific preprocessing for this model

# %%
roberta_df = reviews_data.copy()

# %%
roberta_df['Text'] = roberta_df['Text'].apply(lambda x: preprocessing(x, tokenize=False, lowercasing=False, remove_numbers=False, remove_punctuation=False))

# %%
roberta_df['Label'] = roberta_df['PositiveReviews'].astype(int)

# %%
roberta_df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score       Time  \
# 0                     1                       1      5 2011-04-27
# 1                     0                       0      1 2012-09-07
# 2                     1                       1      4 2008-08-18
# 3                     3                       3      2 2011-06-13
# 4                     0                       0      5 2012-10-21
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...
#
#    IsDuplicate  Month  Year YearMonth  PositiveReviews  NegativeReviews  \
# 0        False      4  2011   2011-04             True            False
# 1        False      9  2012   2012-09            False             True
# 2        False      8  2008   2008-08             True            False
# 3         True      6  2011   2011-06            False             True
# 4        False     10  2012   2012-10             True            False
#
#    NeutralReviews  ReviewLength  Label
# 0           False           263      1
# 1           False           190      0
# 2           False           509      1
# 3           False           219      0
# 4           False           140      1

# %%
from transformers import RobertaTokenizer, TFRobertaForSequenceClassification
from transformers import pipeline

# Load the tokenizer and model
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
model = TFRobertaForSequenceClassification.from_pretrained('roberta-base')

# Initialize a pipeline for sentiment analysis
nlp = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer, truncation=True)


# Tokenizing text data
# The tokenizer handles necessary preprocessing like adding special tokens
encoded_input = tokenizer(roberta_df['Text'].tolist(), padding=True, truncation=True, max_length=512, return_tensors='tf')
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaForSequenceClassification: ['roberta.embeddings.position_ids']
# - This IS expected if you are initializing TFRobertaForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Directly using the pipeline for sentiment analysis
results = nlp(roberta_df['Text'].tolist())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32180\1936458365.py in ?()
#       1 # Directly using the pipeline for sentiment analysis
# ----> 2 results = nlp(roberta_df['Text'].tolist())
#       3
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\transformers\pipelines\text_classification.py in ?(self, inputs, **kwargs)
#     152
#     153             If `top_k` is used, one such dictionary is returned per label.
#     154         """
#     155         inputs = (inputs,)
# --> 156         result = super().__call__(*inputs, **kwargs)
#     157         # TODO try and retrieve it in a nicer way from _sanitize_parameters.
#     158         _legacy = "top_k" not in kwargs
#     159         if isinstance(inputs[0], str) and _legacy:
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\transformers\pipelines\base.py in ?(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1186                 )
#    1187                 outputs = list(final_iterator)
#    1188                 return outputs
#    1189             else:
# -> 1190                 return self.run_multi(inputs, preprocess_params, forward_params, postprocess_params)
#    1191         elif can_use_iterator:
#    1192             return self.get_iterator(
#    1193                 inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\transformers\pipelines\base.py in ?(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1208     def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):
# -> 1209         return [self.run_single(item, preprocess_params, forward_params, postprocess_params) for item in inputs]
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\transformers\pipelines\base.py in ?(.0)
# -> 1209     def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1210         return [self.run_single(item, preprocess_params, forward_params, postprocess_params) for item in inputs]
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\transformers\pipelines\base.py in ?(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1211     def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1212         model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1213         model_outputs = self.forward(model_inputs, **forward_params)
#    1214         outputs = self.postprocess(model_outputs, **postprocess_params)
#    1215         return outputs
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\transformers\pipelines\base.py in ?(self, model_inputs, **forward_params)
#    1103     def forward(self, model_inputs, **forward_params):
#    1104         with self.device_placement():
#    1105             if self.framework == "tf":
#    1106                 model_inputs["training"] = False
# -> 1107                 model_outputs = self._forward(model_inputs, **forward_params)
#    1108             elif self.framework == "pt":
#    1109                 inference_context = self.get_inference_context()
#    1110                 with inference_context():
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\transformers\pipelines\text_classification.py in ?(self, model_inputs)
#     183         # `XXXForSequenceClassification` models should not use `use_cache=True` even if it's supported
#     184         model_forward = self.model.forward if self.framework == "pt" else self.model.call
#     185         if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     186             model_inputs["use_cache"] = False
# --> 187         return self.model(**model_inputs)
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\engine\training.py in ?(self, *args, **kwargs)
#     584                 super().__call__(inputs, *copied_args, **copied_kwargs)
#     585
#     586             layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     587
# --> 588         return super().__call__(*args, **kwargs)
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1132
#    1133                 with autocast_variable.enable_auto_cast_variables(
#    1134                     self._compute_dtype_object
#    1135                 ):
# -> 1136                     outputs = call_fn(inputs, *args, **kwargs)
#    1137
#    1138                 if self._activity_regularizer:
#    1139                     self._handle_activity_regularization(inputs, outputs)
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\transformers\modeling_tf_utils.py in ?(self, *args, **kwargs)
#     433         else:
#     434             config = self.config
#     435
#     436         unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 437         return func(self, **unpacked_inputs)
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\transformers\models\roberta\modeling_tf_roberta.py in ?(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, labels, training)
#    1437             Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1438             config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1439             `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1440         """
# -> 1441         outputs = self.roberta(
#    1442             input_ids,
#    1443             attention_mask=attention_mask,
#    1444             token_type_ids=token_type_ids,
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1132
#    1133                 with autocast_variable.enable_auto_cast_variables(
#    1134                     self._compute_dtype_object
#    1135                 ):
# -> 1136                     outputs = call_fn(inputs, *args, **kwargs)
#    1137
#    1138                 if self._activity_regularizer:
#    1139                     self._handle_activity_regularization(inputs, outputs)
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\transformers\modeling_tf_utils.py in ?(self, *args, **kwargs)
#     433         else:
#     434             config = self.config
#     435
#     436         unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 437         return func(self, **unpacked_inputs)
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\transformers\models\roberta\modeling_tf_roberta.py in ?(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, training)
#     832             raise NotImplementedError
#     833         else:
#     834             head_mask = [None] * self.config.num_hidden_layers
#     835
# --> 836         encoder_outputs = self.encoder(
#     837             hidden_states=embedding_output,
#     838             attention_mask=extended_attention_mask,
#     839             head_mask=head_mask,
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1132
#    1133                 with autocast_variable.enable_auto_cast_variables(
#    1134                     self._compute_dtype_object
#    1135                 ):
# -> 1136                     outputs = call_fn(inputs, *args, **kwargs)
#    1137
#    1138                 if self._activity_regularizer:
#    1139                     self._handle_activity_regularization(inputs, outputs)
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\transformers\models\roberta\modeling_tf_roberta.py in ?(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, training)
#     621                 all_hidden_states = all_hidden_states + (hidden_states,)
#     622
#     623             past_key_value = past_key_values[i] if past_key_values is not None else None
#     624
# --> 625             layer_outputs = layer_module(
#     626                 hidden_states=hidden_states,
#     627                 attention_mask=attention_mask,
#     628                 head_mask=head_mask[i],
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1132
#    1133                 with autocast_variable.enable_auto_cast_variables(
#    1134                     self._compute_dtype_object
#    1135                 ):
# -> 1136                     outputs = call_fn(inputs, *args, **kwargs)
#    1137
#    1138                 if self._activity_regularizer:
#    1139                     self._handle_activity_regularization(inputs, outputs)
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\transformers\models\roberta\modeling_tf_roberta.py in ?(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions, training)
#     513         training: bool = False,
#     514     ) -> Tuple[tf.Tensor]:
#     515         # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     516         self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 517         self_attention_outputs = self.attention(
#     518             input_tensor=hidden_states,
#     519             attention_mask=attention_mask,
#     520             head_mask=head_mask,
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1132
#    1133                 with autocast_variable.enable_auto_cast_variables(
#    1134                     self._compute_dtype_object
#    1135                 ):
# -> 1136                     outputs = call_fn(inputs, *args, **kwargs)
#    1137
#    1138                 if self._activity_regularizer:
#    1139                     self._handle_activity_regularization(inputs, outputs)
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\transformers\models\roberta\modeling_tf_roberta.py in ?(self, input_tensor, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions, training)
#     394         past_key_value: Tuple[tf.Tensor],
#     395         output_attentions: bool,
#     396         training: bool = False,
#     397     ) -> Tuple[tf.Tensor]:
# --> 398         self_outputs = self.self_attention(
#     399             hidden_states=input_tensor,
#     400             attention_mask=attention_mask,
#     401             head_mask=head_mask,
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1132
#    1133                 with autocast_variable.enable_auto_cast_variables(
#    1134                     self._compute_dtype_object
#    1135                 ):
# -> 1136                     outputs = call_fn(inputs, *args, **kwargs)
#    1137
#    1138                 if self._activity_regularizer:
#    1139                     self._handle_activity_regularization(inputs, outputs)
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\transformers\models\roberta\modeling_tf_roberta.py in ?(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions, training)
#     309         attention_probs = stable_softmax(logits=attention_scores, axis=-1)
#     310
#     311         # This is actually dropping out entire tokens to attend to, which might
#     312         # seem a bit unusual, but is taken from the original Transformer paper.
# --> 313         attention_probs = self.dropout(inputs=attention_probs, training=training)
#     314
#     315         # Mask heads if we want to
#     316         if head_mask is not None:
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1132
#    1133                 with autocast_variable.enable_auto_cast_variables(
#    1134                     self._compute_dtype_object
#    1135                 ):
# -> 1136                     outputs = call_fn(inputs, *args, **kwargs)
#    1137
#    1138                 if self._activity_regularizer:
#    1139                     self._handle_activity_regularization(inputs, outputs)
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\layers\regularization\dropout.py in ?(self, inputs, training)
#     116             return self._random_generator.dropout(
#     117                 inputs, self.rate, noise_shape=self._get_noise_shape(inputs)
#     118             )
#     119
# --> 120         output = control_flow_util.smart_cond(
#     121             training, dropped_inputs, lambda: tf.identity(inputs)
#     122         )
#     123         return output
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\utils\control_flow_util.py in ?(pred, true_fn, false_fn, name)
#     104       TypeError: If `true_fn` or `false_fn` is not callable.
#     105     """
#     106     if isinstance(pred, tf.Variable):
#     107         return tf.cond(pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 108     return tf.__internal__.smart_cond.smart_cond(
#     109         pred, true_fn=true_fn, false_fn=false_fn, name=name
#     110     )
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\framework\smart_cond.py in ?(pred, true_fn, false_fn, name)
#      51   if pred_value is not None:
#      52     if pred_value:
#      53       return true_fn()
#      54     else:
# ---> 55       return false_fn()
#      56   else:
#      57     return cond.cond(pred, true_fn=true_fn, false_fn=false_fn,
#      58                      name=name)
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tf_keras\src\layers\regularization\dropout.py in ?()
# --> 121             training, dropped_inputs, lambda: tf.identity(inputs)
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py in ?(*args, **kwargs)
#      86   def wrapper(*args, **kwargs):
#      87     if not ops.is_auto_dtype_conversion_enabled():
# ---> 88       return op(*args, **kwargs)
#      89     bound_arguments = signature.bind(*args, **kwargs)
#      90     bound_arguments.apply_defaults()
#      91     bound_kwargs = bound_arguments.arguments
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\ops\array_ops.py in ?(input, name)
#     306   if context.executing_eagerly() and not hasattr(input, "graph"):
#     307     # Make sure we get an input with handle data attached from resource
#     308     # variables. Variables have correct handle data when graph building.
#     309     input = ops.convert_to_tensor(input)
# --> 310   ret = gen_array_ops.identity(input, name=name)
#     311   # Propagate handle data for happier shape inference for resource variables.
#     312   if hasattr(input, "_handle_data"):
#     313     ret._handle_data = input._handle_data  # pylint: disable=protected-access
#
# c:\Users\sophia.bouchama\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\ops\gen_array_ops.py in ?(input, name)
#    4185         _ctx, "Identity", name, input)
#    4186       return _result
#    4187     except _core._NotOkStatusException as e:
#    4188       _ops.raise_from_not_ok_status(e, name)
# -> 4189     except _core._FallbackException:
#    4190       pass
#    4191     try:
#    4192       return identity_eager_fallback(
#
# KeyboardInterrupt:
